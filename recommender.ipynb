# %% [markdown]
# # Building a Spotify Recommendation Engine for Music Labels
# ## Recommendation System and Evaluation
# ### Flatiron School Data Science Program Phase 4 Project<br>Justin Williams & Khyatee Desai

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from zipfile import ZipFile 
from sklearn import set_config
set_config(print_changed_only=False, display=None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
% matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import Cleaned Data

# %%
df = pd.read_csv('data/cleaned_data.csv',index_col=[0])
df.head()
# Out:
#    acousticness  danceability  duration_ms  energy  explicit  \
# 0         0.968         0.589     281078.0   0.383       0.0
# 1         0.981         0.602     182282.0   0.488       0.0
# 2         0.965         0.554      86753.0   0.446       0.0
# 3         0.802         0.409     193123.0   0.672       0.0
# 4         0.838         0.599      65698.0   0.321       0.0
#
#                        id  instrumentalness  key  liveness  loudness  mode  \
# 0  5DtPYDt4rEBfcH2KD2rmlA           0.04200  8.0     0.165   -10.225   1.0
# 1  5EVQBCdoCVmpQV4lfRLsQg           0.00308  8.0     0.167   -10.391   1.0
# 2  571B5Z1tC8u6GhVBdhEr9D           0.68800  7.0     0.143   -13.002   1.0
# 3  1i8C8u3CVtM4NmaPGNXBNk           0.49400  9.0     0.313    -8.601   1.0
# 4  1lgnLRxxnFqaXxMlZNyWKj           0.00000  2.0     0.156    -9.407   0.0
#
#                                    name  popularity release_date  speechiness  \
# 0                Matchbox Blues (141-B)         0.0   1935-01-01     0.146614
# 1  Death Letter Blues - Part 2 (Take 1)         0.0   1935-01-01     0.047200
# 2         Blind Lemon (Memorial Record)         0.0   1947-01-01     0.044000
# 3                            John Henry         0.0   1949-01-01     0.040900
# 4           Come And Sit Down Beside Me         0.0   1949-01-01     0.035400
#
#      tempo  valence  year      artist      label letter_keys  modes  \
# 0   82.538    0.719  1935  Lead Belly  Third Man          Ab  Major
# 1  151.152    0.621  1935  Lead Belly  Third Man          Ab  Major
# 2   96.644    0.973  1947  Lead Belly  Third Man           G  Major
# 3  145.218    0.731  1949  Lead Belly  Third Man           A  Major
# 4   87.006    0.919  1949  Lead Belly  Third Man           D  Minor
#
#    scaled_speech  scaled_duration  scaled_loudness  scaled_tempo  scaled_pop  \
# 0       0.702688         0.375765         0.618709      0.267285         0.0
# 1       0.138479         0.232547         0.614178      0.630084         0.0
# 2       0.120318         0.094065         0.542910      0.341871         0.0
# 3       0.102724         0.248263         0.663037      0.598708         0.0
# 4       0.071510         0.063543         0.641037      0.290910         0.0
#
#   decade  key_mode
# 0  1930s  Ab Major
# 1  1930s  Ab Major
# 2  1940s   G Major
# 3  1940s   A Major
# 4  1940s   D Minor
